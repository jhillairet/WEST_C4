# %%
# %matplotlib notebook

# %%
import sys; sys.path.append('..')

# %%
from control_room import *
import imas_west
from pywed import *

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 54525

# %%
pulse = 54525
PQ1, tQ1 = get_sig(pulse, signals['IC_P_Q1'])
PQ4, tQ4 = get_sig(pulse, signals['IC_P_Q4'])
output = imas_west.get(pulse, 'bolometer')

fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
ax1.plot(output.time - 32, output.power_radiated_total/1e3, lw=2, label='Total Rad.Power')
ax2.plot(tQ1, PQ1, lw=2, label='Q1', color='C1')
ax2.plot(tQ4, PQ4, lw=2, label='Q4', color='C2')
ax1.set_xlim(0, 10)
ax2.legend()
[a.set_ylabel('P [kW]', fontsize=14) for a in (ax1, ax2)]
[a.grid(True, alpha=.4) for a in (ax1, ax2)]
ax2.set_xlabel('t [s]', fontsize=14)
fig.subplots_adjust(hspace=.1)
ax1.set_title(f'WEST #{pulse}')
fig.savefig(f'WEST_{pulse}_Prad_vs_IC.png', dpi=150)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## 54414

# %%
pulse = 54514
PQ2, tQ2 = get_sig(pulse, signals['IC_P_Q2'])
PQ4, tQ4 = get_sig(pulse, signals['IC_P_Q4'])
output = imas_west.get(pulse, 'bolometer')

fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
ax1.plot(output.time - 32, output.power_radiated_total/1e3, lw=2, label='Total Rad.Power')
ax2.plot(tQ2, PQ2, lw=2, label='Q2', color='C3')
ax2.plot(tQ4, PQ4, lw=2, label='Q4', color='C2')
ax1.set_xlim(0, 10)
ax2.legend()
[a.set_ylabel('P [kW]', fontsize=14) for a in (ax1, ax2)]
[a.grid(True, alpha=.4) for a in (ax1, ax2)]
ax2.set_xlabel('t [s]', fontsize=14)
fig.subplots_adjust(hspace=.1)
ax1.set_title(f'WEST #{pulse}')
fig.savefig(f'WEST_{pulse}_Prad_vs_IC.png', dpi=150)
# Out:
#
# shot       = 54514
# ids_name   = bolometer
# run        = 0
# occurrence = 0
# user       = imas_public
# machine    = west
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## 54537, 54538, 54544

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)

pulse = 54537
PQ2, tQ2 = get_sig(pulse, signals['IC_P_Q2'])
output = imas_west.get(pulse, 'bolometer')
ax1.plot(output.time - 32, output.power_radiated_total/1e3, lw=2, label=f'Total Rad.Power - {pulse}')
ax2.plot(tQ2, PQ2, label=f'Q2 - {pulse}')

pulse = 54544
PQ2, tQ2 = get_sig(pulse, signals['IC_P_Q2'])
output = imas_west.get(pulse, 'bolometer')
ax1.plot(output.time - 32, output.power_radiated_total/1e3, lw=2, label=f'Total Rad.Power - {pulse}')
ax2.plot(tQ2, PQ2, label=f'Q2 - {pulse}')

pulse = 54545
PQ2, tQ2 = get_sig(pulse, signals['IC_P_Q2'])
output = imas_west.get(pulse, 'bolometer')
ax1.plot(output.time - 32, output.power_radiated_total/1e3, lw=2, label=f'Total Rad.Power - {pulse}')
ax2.plot(tQ2, PQ2, label=f'Q2 - {pulse}')

ax1.set_xlim(0, 10)
ax2.legend()
[a.set_ylabel('P [kW]', fontsize=14) for a in (ax1, ax2)]
[a.grid(True, alpha=.4) for a in (ax1, ax2)]
ax2.set_xlabel('t [s]', fontsize=14)
fig.subplots_adjust(hspace=.1)
ax1.set_title(f'WEST #{pulse}')
# Out:
# <img src="data:image/png;base64,..." width="640">
#
# shot       = 54537
# ids_name   = bolometer
# run        = 0
# occurrence = 0
# user       = imas_public
# machine    = west
#
#
# shot       = 54544
# ids_name   = bolometer
# run        = 0
# occurrence = 0
# user       = imas_public
# machine    = west
#
#
# shot       = 54545
# ids_name   = bolometer
# run        = 0
# occurrence = 0
# user       = imas_public
# machine    = west
# Text(0.5, 1.0, 'WEST #54545')
