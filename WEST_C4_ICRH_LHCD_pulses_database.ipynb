# %% [markdown]
# # WEST C4 ICRH pulses database

# %% [markdown]
# In this notebook we generate a database of the pulses in which ICRH has been used.
#
# In theory, the IRFM GED could be used for that... In theory.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('C:/Users/JH218595/Documents/pywed')
sys.path.append('C:/Users/JH218595/Documents/IRFMtb/')

# %%
import pywed as pw
import numpy as np

from control_room import *
import matplotlib.pyplot as plt 
from pulse_database import PulseDB
from tqdm.notebook import tqdm

# %% [markdown]
# # Listing the pulses

# %% [markdown]
# Make a list of all the pulses to analyze:

# %%
hdf5_filename = 'databases/WEST_C4_ICRH_LHCD_pulse_data.hdf5'
db = PulseDB(hdf5_filename)

# %%
# Below we add the pulse number for which Total RF Power has been used (>250k W).
db.update_pulse_list(ref_sig=signals['RF_P_tot'], thres=0.25)
# Out:
# IMAS only available on linux machines
# Going from 54404 to 55994
# SHYBPTOT #54408: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54408: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SHYBPTOT #54409: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54409: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# C:\Users\JH218595\Documents\WEST_C4\control_room.py:592: RuntimeWarning: invalid value encountered in greater_equal
#   if np.any(y >= thres):
# SHYBPTOT #54414: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54415: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54416: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54417: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54417: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SHYBPTOT #54418: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54419: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54419: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54420: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54420: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54421: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54421: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54422: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54422: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54423: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54423: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54424: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54424: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SHYBPTOT #54425: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54426: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54427: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54431: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54431: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SHYBPTOT #54434: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54434: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54450: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54450: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SHYBPTOT #54452: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54453: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54454: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54474: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SICHPTOT #54481: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54482: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54483: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54484: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54485: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54486: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54487: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54488: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54489: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54489: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54490: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54491: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54492: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54493: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54493: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54494: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54494: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54495: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54495: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54496: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54496: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54497: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54497: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54498: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54498: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54499: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54499: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54500: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54500: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54501: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54501: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54513: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54514: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54515: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54516: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54517: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54518: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54518: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SHYBPTOT #54519: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54520: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54521: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54522: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54523: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54524: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54526: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54526: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SHYBPTOT #54541: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54541: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SICHPTOT #54554: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SICHPTOT #54555: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SICHPTOT #54556: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SICHPTOT #54557: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SHYBPTOT #54558: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SICHPTOT #54558: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SHYBPTOT #54569: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54569: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SHYBPTOT #54583: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54584: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54585: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54586: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54587: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54588: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54589: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54590: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54591: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54592: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54593: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54594: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54595: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54598: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54598: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SHYBPTOT #54615: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54616: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54617: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54618: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54619: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54620: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54621: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54622: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54623: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54624: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54625: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54632: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54633: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54634: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54635: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54636: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54637: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54638: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54654: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54654: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SHYBPTOT #54656: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54702: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SICHPTOT #54702: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SHYBPTOT #54710: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54710: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SHYBPTOT #54712: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54713: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54714: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54715: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54715: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54716: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54716: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54717: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54717: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54718: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54718: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54720: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54720: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SHYBPTOT #54737: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54738: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54739: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54740: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54741: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54742: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54743: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54743: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SHYBPTOT #54744: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54789: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54789: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SHYBPTOT #54790: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54790: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SICHPTOT #54793: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54794: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54795: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54796: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54797: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54798: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54799: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54800: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54801: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54802: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54803: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54804: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54805: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54806: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SICHPTOT #54806: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SICHPTOT #54807: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54808: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54809: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54810: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54811: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54812: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54813: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54814: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54815: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54816: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54817: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54818: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54819: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54820: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54821: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54822: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54823: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54824: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54825: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54826: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54827: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54828: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54829: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54830: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54831: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54832: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54833: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54834: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54835: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54836: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54837: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54838: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54839: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54839: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54840: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SICHPTOT #54840: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SHYBPTOT #54841: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SICHPTOT #54841: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SHYBPTOT #54842: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SICHPTOT #54842: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SHYBPTOT #54843: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SICHPTOT #54843: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SHYBPTOT #54844: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SICHPTOT #54844: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SHYBPTOT #54845: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SICHPTOT #54845: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SHYBPTOT #54846: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SICHPTOT #54846: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SHYBPTOT #54847: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SICHPTOT #54847: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SHYBPTOT #54848: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SICHPTOT #54848: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SHYBPTOT #54849: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54849: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54850: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54850: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54851: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54851: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54852: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54852: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54853: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54853: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54854: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54854: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54855: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54855: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54856: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54856: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54857: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54857: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54858: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54858: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54859: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54859: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54860: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54860: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54861: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54861: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54862: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54862: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54863: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54863: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54864: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54864: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54865: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54865: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54866: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54866: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54867: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54867: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54868: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54868: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54869: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54869: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54870: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54870: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54871: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54871: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54872: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54872: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54873: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54873: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54874: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54874: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54875: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54875: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54876: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54876: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54877: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54877: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54878: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54879: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54880: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54885: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SICHPTOT #54885: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SHYBPTOT #54888: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54888: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SHYBPTOT #54889: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54889: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SHYBPTOT #54890: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54890: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SHYBPTOT #54894: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54895: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54896: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54897: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54898: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54899: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54900: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54901: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54902: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54903: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54904: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54905: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54905: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54906: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54906: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54907: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54907: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54908: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54908: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54909: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54909: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54910: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54910: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54911: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54911: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54912: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54913: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54913: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54914: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54915: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54916: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54917: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54918: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54919: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54920: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54920: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54921: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54922: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54923: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54924: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54925: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54926: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54927: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54928: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54929: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54930: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54931: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54932: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54933: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54933: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54934: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54935: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SICHPTOT #54935: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54936: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54937: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54938: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54939: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54940: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54941: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #54942: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #54942: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# ...
# SHYBPTOT #55895: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55895: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #55896: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 32: 'Non-acquired data'
# SICHPTOT #55896: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55897: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55898: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55899: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55900: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55901: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55902: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55903: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55904: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55905: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55906: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55907: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55908: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55909: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55910: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55911: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55912: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55913: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55914: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55915: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55916: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #55917: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55917: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55918: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55919: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55920: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55921: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55922: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55923: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55924: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55925: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55926: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55927: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55928: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55929: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55930: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #55931: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55931: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55932: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55933: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55934: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55935: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55936: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55937: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55938: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55939: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55940: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55941: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55942: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55943: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# You're asking a lot of data, please wait
# SICHPTOT #55944: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55945: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55946: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55947: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #55948: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55948: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55949: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55950: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55951: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55952: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55953: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55954: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #55955: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55955: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55956: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #55957: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SICHPTOT #55957: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SHYBPTOT #55958: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SICHPTOT #55958: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SHYBPTOT #55959: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SICHPTOT #55959: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SICHPTOT #55960: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55961: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55962: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55963: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55964: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55965: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55966: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55967: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #55968: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55968: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55969: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55970: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55971: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55972: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55973: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55974: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55975: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55976: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55977: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55978: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55979: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55980: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55981: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55982: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55983: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55984: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55985: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55986: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SICHPTOT #55987: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 9: 'Non-generated data for this shot'
# SHYBPTOT #55988: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SICHPTOT #55988: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SHYBPTOT #55989: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SICHPTOT #55989: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SHYBPTOT #55990: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SICHPTOT #55990: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SHYBPTOT #55991: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SICHPTOT #55991: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SHYBPTOT #55992: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SICHPTOT #55992: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SHYBPTOT #55993: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SICHPTOT #55993: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SHYBPTOT #55994: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'
# SICHPTOT #55994: [Exception tsExQueryError in PyWED] [Query Error] Invalid query, server returned 7: 'Missing treatment for this shot'

# %%
db.pulse_list
# Out:
# [54404,
#  54405,
#  54406,
#  54407,
#  54410,
#  54411,
#  54412,
#  54413,
#  54429,
#  54432,
#  54435,
#  54436,
#  54440,
#  54441,
#  54442,
#  54443,
#  54444,
#  54445,
#  54446,
#  54447,
#  54448,
#  54449,
#  54455,
#  54456,
#  54457,
#  54458,
#  54459,
#  54460,
#  54461,
#  54462,
#  54472,
#  54473,
#  54475,
#  54476,
#  54477,
#  54508,
#  54509,
#  54510,
#  54511,
#  54512,
#  54525,
#  54527,
#  54528,
#  54529,
#  54530,
#  54532,
#  54533,
#  54534,
#  54535,
#  54536,
#  54537,
#  54538,
#  54540,
#  54544,
#  54545,
#  54546,
#  54548,
#  54550,
#  54551,
#  54552,
#  54553,
#  54559,
#  54561,
#  54562,
#  54563,
#  54565,
#  54566,
#  54567,
#  54568,
#  54571,
#  54573,
#  54574,
#  54575,
#  54576,
#  54577,
#  54578,
#  54579,
#  54581,
#  54582,
#  54597,
#  54599,
#  54600,
#  54601,
#  54602,
#  54603,
#  54605,
#  54606,
#  54607,
#  54608,
#  54609,
#  54610,
#  54611,
#  54612,
#  54614,
#  54627,
#  54628,
#  54629,
#  54630,
#  54631,
#  54639,
#  54640,
#  54641,
#  54642,
#  54644,
#  54645,
#  54646,
#  54647,
#  54648,
#  54651,
#  54652,
#  54653,
#  54655,
#  54657,
#  54658,
#  54659,
#  54660,
#  54661,
#  54662,
#  54663,
#  54664,
#  54665,
#  54666,
#  54667,
#  54668,
#  54669,
#  54670,
#  54672,
#  54673,
#  54674,
#  54675,
#  54676,
#  54677,
#  54678,
#  54679,
#  54680,
#  54681,
#  54682,
#  54683,
#  54684,
#  54685,
#  54686,
#  54687,
#  54689,
#  54690,
#  54694,
#  54695,
#  54696,
#  54697,
#  54698,
#  54699,
#  54701,
#  54703,
#  54706,
#  54707,
#  54708,
#  54709,
#  54711,
#  54719,
#  54721,
#  54724,
#  54725,
#  54727,
#  54728,
#  54729,
#  54731,
#  54732,
#  54733,
#  54734,
#  54736,
#  54745,
#  54746,
#  54748,
#  54749,
#  54750,
#  54751,
#  54752,
#  54753,
#  54754,
#  54755,
#  54756,
#  54757,
#  54758,
#  54760,
#  54761,
#  54762,
#  54764,
#  54765,
#  54766,
#  54767,
#  54768,
#  54769,
#  54770,
#  54771,
#  54772,
#  54773,
#  54774,
#  54777,
#  54780,
#  54781,
#  54783,
#  54785,
#  54788,
#  54792,
#  54882,
#  54883,
#  54884,
#  54886,
#  54887,
#  54891,
#  54892,
#  54893,
#  55009,
#  55010,
#  55011,
#  55025,
#  55026,
#  55029,
#  55030,
#  55031,
#  55033,
#  55034,
#  55035,
#  55036,
#  55037,
#  55038,
#  55039,
#  55040,
#  55044,
#  55045,
#  55046,
#  55047,
#  55048,
#  55049,
#  55050,
#  55051,
#  55052,
#  55054,
#  55056,
#  55058,
#  55059,
#  55062,
#  55064,
#  55066,
#  55067,
#  55068,
#  55069,
#  55070,
#  55073,
#  55074,
#  55076,
#  55077,
#  55080,
#  55081,
#  55082,
#  55083,
#  55084,
#  55085,
#  55087,
#  55088,
#  55089,
#  55091,
#  55092,
#  55095,
#  55096,
#  55097,
#  55098,
#  55099,
#  55100,
#  55102,
#  55106,
#  55107,
#  55141,
#  55142,
#  55143,
#  55144,
#  55145,
#  55146,
#  55147,
#  55148,
#  55159,
#  55160,
#  55161,
#  55170,
#  55171,
#  55172,
#  55175,
#  55176,
#  55177,
#  55178,
#  55179,
#  55180,
#  55181,
#  55184,
#  55185,
#  55187,
#  55188,
#  55189,
#  55192,
#  55193,
#  55194,
#  55195,
#  55196,
#  55197,
#  55198,
#  55199,
#  55200,
#  55201,
#  55202,
#  55203,
#  55204,
#  55205,
#  55206,
#  55207,
#  55209,
#  55210,
#  55214,
#  55215,
#  55216,
#  55217,
#  55218,
#  55219,
#  55220,
#  55221,
#  55222,
#  55336,
#  55337,
#  55338,
#  55339,
#  55340,
#  55341,
#  55342,
#  55343,
#  55344,
#  55345,
#  55346,
#  55347,
#  55348,
#  55349,
#  55500,
#  55501,
#  55502,
#  55503,
#  55505,
#  55506,
#  55507,
#  55508,
#  55509,
#  55510,
#  55511,
#  55512,
#  55513,
#  55517,
#  55518,
#  55519,
#  55521,
#  55522,
#  55524,
#  55525,
#  55526,
#  55527,
#  55528,
#  55530,
#  55531,
#  55532,
#  55533,
#  55534,
#  55535,
#  55536,
#  55537,
#  55538,
#  55539,
#  55540,
#  55541,
#  55550,
#  55551,
#  55552,
#  55554,
#  55555,
#  55556,
#  55557,
#  55560,
#  55561,
#  55562,
#  55563,
#  55564,
#  55565,
#  55566,
#  55567,
#  55568,
#  55569,
#  55570,
#  55628,
#  55629,
#  55630,
#  55631,
#  55633,
#  55635,
#  55636,
#  55637,
#  55638,
#  55639,
#  55640,
#  55643,
#  55644,
#  55646,
#  55665,
#  55676,
#  55677,
#  55678,
#  55679,
#  55680,
#  55681,
#  55682,
#  55722,
#  55723,
#  55724,
#  55725,
#  55728,
#  55731,
#  55768,
#  55769,
#  55770,
#  55771,
#  55772,
#  55774,
#  55777,
#  55778,
#  55779,
#  55780,
#  55781,
#  55782,
#  55783,
#  55784,
#  55785,
#  55786,
#  55787,
#  55789,
#  55790,
#  55791,
#  55792,
#  55794,
#  55796,
#  55797,
#  55799,
#  55800,
#  55801,
#  55802,
#  55803,
#  55804,
#  55805,
#  55807,
#  55808,
#  55809]

# %%
# save the pulse list in a text file
np.savetxt('WEST_C4_IC_LH_pulse_list.txt', db.pulse_list, fmt='%i')

# %% [markdown]
# # Filling the database

# %%
# Adding new signals to the database
#db.delete_signals(['LH_Positions', 'IC_Positions', 'IC_Frequencies'])
signal_names = [#'IC_Capa_Q1_left_upper', 'IC_Capa_Q1_left_lower', 'IC_Capa_Q1_right_upper', 'IC_Capa_Q1_right_lower',
                #'IC_Capa_Q2_left_upper', 'IC_Capa_Q2_left_lower', 'IC_Capa_Q2_right_upper', 'IC_Capa_Q2_right_lower', 
                #'IC_Capa_Q4_left_upper', 'IC_Capa_Q4_left_lower', 'IC_Capa_Q4_right_upper', 'IC_Capa_Q4_right_lower',
                #'LPA', 
                'IC_Positions', 'LH_Positions', 
                #'IC_Vacuum_Q1_left', 'IC_Vacuum_Q1_right', 
                #'IC_Vacuum_Q2_left', 'IC_Vacuum_Q2_right',
                #'IC_Vacuum_Q4_left', 'IC_Vacuum_Q4_right',
                #'Langmuir_LHCD1', 'Langmuir_LHCD2', 'Langmuir_LHCD3', 'Langmuir_LHCD4',
                #'Langmuir_LHCD5', 'Langmuir_LHCD6', 'Langmuir_LHCD7' ,'Langmuir_LHCD8' ,
                'Prad',
                'Prad_bulk',
                'Rext_median',
                'Ip', 'nl',
                #'IC_Frequencies', 
                'IC_P_Q1', 'IC_P_Q2', 'IC_P_Q4',  
                'IC_P_tot', 'LH_P_tot',
                'IC_Rc_Q1_avg', 'IC_Rc_Q2_avg', 'IC_Rc_Q4_avg',
                #'IC_Voltage_left_upper_Q1', 'IC_Voltage_left_lower_Q1', 
                #'IC_Voltage_right_upper_Q1', 'IC_Voltage_right_lower_Q1',
                #'IC_Voltage_left_upper_Q2', 'IC_Voltage_left_lower_Q2', 
                #'IC_Voltage_right_upper_Q2', 'IC_Voltage_right_lower_Q2',
                #'IC_Voltage_left_upper_Q4', 'IC_Voltage_left_lower_Q4', 
                #'IC_Voltage_right_upper_Q4', 'IC_Voltage_right_lower_Q4',
                #'IC_delta_phi_toro_Q1_Top_LmR', 'IC_delta_phi_toro_Q1_Bot_LmR',
                #'IC_delta_phi_toro_Q2_Top_LmR', 'IC_delta_phi_toro_Q2_Bot_LmR',
                #'IC_delta_phi_toro_Q4_Top_LmR', 'IC_delta_phi_toro_Q4_Bot_LmR',
                'Ohmic_P', 'Separatrix_P',
                #'Neutron1',
                #'Ag18', 'Ag19',
]


for pulse in tqdm(db.pulse_list):
    db.add_signals(int(pulse), signal_names)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=453.0), HTML(value='')))
# IC_Positions already exist in database for #54404: passing...
# LH_Positions already exist in database for #54404: passing...
# Prad already exist in database for #54404: passing...
# Prad_bulk already exist in database for #54404: passing...
# Rext_median already exist in database for #54404: passing...
# Ip already exist in database for #54404: passing...
# nl already exist in database for #54404: passing...
# IC_P_Q1 already exist in database for #54404: passing...
# IC_P_Q2 already exist in database for #54404: passing...
# IC_P_Q4 already exist in database for #54404: passing...
# IC_P_tot already exist in database for #54404: passing...
# LH_P_tot already exist in database for #54404: passing...
# IC_Rc_Q1_avg already exist in database for #54404: passing...
# IC_Rc_Q2_avg already exist in database for #54404: passing...
# IC_Rc_Q4_avg already exist in database for #54404: passing...
# Ohmic_P already exist in database for #54404: passing...
# Separatrix_P already exist in database for #54404: passing...
# IC_Positions already exist in database for #54405: passing...
# LH_Positions already exist in database for #54405: passing...
# Prad already exist in database for #54405: passing...
# Prad_bulk already exist in database for #54405: passing...
# Rext_median already exist in database for #54405: passing...
# Ip already exist in database for #54405: passing...
# nl already exist in database for #54405: passing...
# IC_P_Q1 already exist in database for #54405: passing...
# IC_P_Q2 already exist in database for #54405: passing...
# IC_P_Q4 already exist in database for #54405: passing...
# IC_P_tot already exist in database for #54405: passing...
# LH_P_tot already exist in database for #54405: passing...
# IC_Rc_Q1_avg already exist in database for #54405: passing...
# IC_Rc_Q2_avg already exist in database for #54405: passing...
# IC_Rc_Q4_avg already exist in database for #54405: passing...
# Ohmic_P already exist in database for #54405: passing...
# Separatrix_P already exist in database for #54405: passing...
# IC_Positions already exist in database for #54406: passing...
# LH_Positions already exist in database for #54406: passing...
# Prad already exist in database for #54406: passing...
# Prad_bulk already exist in database for #54406: passing...
# Rext_median already exist in database for #54406: passing...
# Ip already exist in database for #54406: passing...
# nl already exist in database for #54406: passing...
# IC_P_Q1 already exist in database for #54406: passing...
# IC_P_Q2 already exist in database for #54406: passing...
# IC_P_Q4 already exist in database for #54406: passing...
# IC_P_tot already exist in database for #54406: passing...
# LH_P_tot already exist in database for #54406: passing...
# IC_Rc_Q1_avg already exist in database for #54406: passing...
# IC_Rc_Q2_avg already exist in database for #54406: passing...
# IC_Rc_Q4_avg already exist in database for #54406: passing...
# Ohmic_P already exist in database for #54406: passing...
# Separatrix_P already exist in database for #54406: passing...
# IC_Positions already exist in database for #54407: passing...
# LH_Positions already exist in database for #54407: passing...
# Prad already exist in database for #54407: passing...
# Prad_bulk already exist in database for #54407: passing...
# Rext_median already exist in database for #54407: passing...
# Ip already exist in database for #54407: passing...
# nl already exist in database for #54407: passing...
# IC_P_Q1 already exist in database for #54407: passing...
# IC_P_Q2 already exist in database for #54407: passing...
# IC_P_Q4 already exist in database for #54407: passing...
# IC_P_tot already exist in database for #54407: passing...
# LH_P_tot already exist in database for #54407: passing...
# IC_Rc_Q1_avg already exist in database for #54407: passing...
# IC_Rc_Q2_avg already exist in database for #54407: passing...
# IC_Rc_Q4_avg already exist in database for #54407: passing...
# Ohmic_P already exist in database for #54407: passing...
# Separatrix_P already exist in database for #54407: passing...
# IC_Positions already exist in database for #54410: passing...
# LH_Positions already exist in database for #54410: passing...
# Prad already exist in database for #54410: passing...
# Prad_bulk already exist in database for #54410: passing...
# Rext_median already exist in database for #54410: passing...
# Ip already exist in database for #54410: passing...
# nl already exist in database for #54410: passing...
# IC_P_Q1 already exist in database for #54410: passing...
# IC_P_Q2 already exist in database for #54410: passing...
# IC_P_Q4 already exist in database for #54410: passing...
# IC_P_tot already exist in database for #54410: passing...
# LH_P_tot already exist in database for #54410: passing...
# IC_Rc_Q1_avg already exist in database for #54410: passing...
# IC_Rc_Q2_avg already exist in database for #54410: passing...
# IC_Rc_Q4_avg already exist in database for #54410: passing...
# Ohmic_P already exist in database for #54410: passing...
# Separatrix_P already exist in database for #54410: passing...
# IC_Positions already exist in database for #54411: passing...
# LH_Positions already exist in database for #54411: passing...
# Prad already exist in database for #54411: passing...
# Prad_bulk already exist in database for #54411: passing...
# Rext_median already exist in database for #54411: passing...
# Ip already exist in database for #54411: passing...
# nl already exist in database for #54411: passing...
# IC_P_Q1 already exist in database for #54411: passing...
# IC_P_Q2 already exist in database for #54411: passing...
# IC_P_Q4 already exist in database for #54411: passing...
# IC_P_tot already exist in database for #54411: passing...
# LH_P_tot already exist in database for #54411: passing...
# IC_Rc_Q1_avg already exist in database for #54411: passing...
# IC_Rc_Q2_avg already exist in database for #54411: passing...
# IC_Rc_Q4_avg already exist in database for #54411: passing...
# Ohmic_P already exist in database for #54411: passing...
# Separatrix_P already exist in database for #54411: passing...
# IC_Positions already exist in database for #54412: passing...
# LH_Positions already exist in database for #54412: passing...
# Prad already exist in database for #54412: passing...
# Prad_bulk already exist in database for #54412: passing...
# Rext_median already exist in database for #54412: passing...
# Ip already exist in database for #54412: passing...
# nl already exist in database for #54412: passing...
# IC_P_Q1 already exist in database for #54412: passing...
# IC_P_Q2 already exist in database for #54412: passing...
# IC_P_Q4 already exist in database for #54412: passing...
# IC_P_tot already exist in database for #54412: passing...
# LH_P_tot already exist in database for #54412: passing...
# IC_Rc_Q1_avg already exist in database for #54412: passing...
# IC_Rc_Q2_avg already exist in database for #54412: passing...
# IC_Rc_Q4_avg already exist in database for #54412: passing...
# Ohmic_P already exist in database for #54412: passing...
# Separatrix_P already exist in database for #54412: passing...
# IC_Positions already exist in database for #54413: passing...
# LH_Positions already exist in database for #54413: passing...
# Prad already exist in database for #54413: passing...
# Prad_bulk already exist in database for #54413: passing...
# Rext_median already exist in database for #54413: passing...
# Ip already exist in database for #54413: passing...
# nl already exist in database for #54413: passing...
# IC_P_Q1 already exist in database for #54413: passing...
# IC_P_Q2 already exist in database for #54413: passing...
# IC_P_Q4 already exist in database for #54413: passing...
# IC_P_tot already exist in database for #54413: passing...
# LH_P_tot already exist in database for #54413: passing...
# IC_Rc_Q1_avg already exist in database for #54413: passing...
# IC_Rc_Q2_avg already exist in database for #54413: passing...
# IC_Rc_Q4_avg already exist in database for #54413: passing...
# Ohmic_P already exist in database for #54413: passing...
# Separatrix_P already exist in database for #54413: passing...
# IC_Positions already exist in database for #54429: passing...
# LH_Positions already exist in database for #54429: passing...
# Prad already exist in database for #54429: passing...
# Prad_bulk already exist in database for #54429: passing...
# Rext_median already exist in database for #54429: passing...
# Ip already exist in database for #54429: passing...
# nl already exist in database for #54429: passing...
# IC_P_Q1 already exist in database for #54429: passing...
# IC_P_Q2 already exist in database for #54429: passing...
# IC_P_Q4 already exist in database for #54429: passing...
# IC_P_tot already exist in database for #54429: passing...
# LH_P_tot already exist in database for #54429: passing...
# IC_Rc_Q1_avg already exist in database for #54429: passing...
# IC_Rc_Q2_avg already exist in database for #54429: passing...
# IC_Rc_Q4_avg already exist in database for #54429: passing...
# Ohmic_P already exist in database for #54429: passing...
# Separatrix_P already exist in database for #54429: passing...
# IC_Positions already exist in database for #54432: passing...
# LH_Positions already exist in database for #54432: passing...
# Prad already exist in database for #54432: passing...
# Prad_bulk already exist in database for #54432: passing...
# Rext_median already exist in database for #54432: passing...
# Ip already exist in database for #54432: passing...
# nl already exist in database for #54432: passing...
# IC_P_Q1 already exist in database for #54432: passing...
# IC_P_Q2 already exist in database for #54432: passing...
# IC_P_Q4 already exist in database for #54432: passing...
# IC_P_tot already exist in database for #54432: passing...
# LH_P_tot already exist in database for #54432: passing...
# IC_Rc_Q1_avg already exist in database for #54432: passing...
# IC_Rc_Q2_avg already exist in database for #54432: passing...
# IC_Rc_Q4_avg already exist in database for #54432: passing...
# Ohmic_P already exist in database for #54432: passing...
# Separatrix_P already exist in database for #54432: passing...
# IC_Positions already exist in database for #54435: passing...
# LH_Positions already exist in database for #54435: passing...
# Prad already exist in database for #54435: passing...
# Prad_bulk already exist in database for #54435: passing...
# Rext_median already exist in database for #54435: passing...
# Ip already exist in database for #54435: passing...
# nl already exist in database for #54435: passing...
# IC_P_Q1 already exist in database for #54435: passing...
# IC_P_Q2 already exist in database for #54435: passing...
# IC_P_Q4 already exist in database for #54435: passing...
# IC_P_tot already exist in database for #54435: passing...
# LH_P_tot already exist in database for #54435: passing...
# IC_Rc_Q1_avg already exist in database for #54435: passing...
# IC_Rc_Q2_avg already exist in database for #54435: passing...
# IC_Rc_Q4_avg already exist in database for #54435: passing...
# Ohmic_P already exist in database for #54435: passing...
# Separatrix_P already exist in database for #54435: passing...
# IC_Positions already exist in database for #54436: passing...
# LH_Positions already exist in database for #54436: passing...
# Prad already exist in database for #54436: passing...
# Prad_bulk already exist in database for #54436: passing...
# Rext_median already exist in database for #54436: passing...
# Ip already exist in database for #54436: passing...
# nl already exist in database for #54436: passing...
# IC_P_Q1 already exist in database for #54436: passing...
# IC_P_Q2 already exist in database for #54436: passing...
# IC_P_Q4 already exist in database for #54436: passing...
# IC_P_tot already exist in database for #54436: passing...
# LH_P_tot already exist in database for #54436: passing...
# IC_Rc_Q1_avg already exist in database for #54436: passing...
# IC_Rc_Q2_avg already exist in database for #54436: passing...
# IC_Rc_Q4_avg already exist in database for #54436: passing...
# Ohmic_P already exist in database for #54436: passing...
# Separatrix_P already exist in database for #54436: passing...
# IC_Positions already exist in database for #54440: passing...
# LH_Positions already exist in database for #54440: passing...
# Prad already exist in database for #54440: passing...
# Prad_bulk already exist in database for #54440: passing...
# Rext_median already exist in database for #54440: passing...
# Ip already exist in database for #54440: passing...
# nl already exist in database for #54440: passing...
# IC_P_Q1 already exist in database for #54440: passing...
# IC_P_Q2 already exist in database for #54440: passing...
# IC_P_Q4 already exist in database for #54440: passing...
# IC_P_tot already exist in database for #54440: passing...
# LH_P_tot already exist in database for #54440: passing...
# IC_Rc_Q1_avg already exist in database for #54440: passing...
# IC_Rc_Q2_avg already exist in database for #54440: passing...
# IC_Rc_Q4_avg already exist in database for #54440: passing...
# Ohmic_P already exist in database for #54440: passing...
# Separatrix_P already exist in database for #54440: passing...
# IC_Positions already exist in database for #54441: passing...
# LH_Positions already exist in database for #54441: passing...
# Prad already exist in database for #54441: passing...
# Prad_bulk already exist in database for #54441: passing...
# Rext_median already exist in database for #54441: passing...
# Ip already exist in database for #54441: passing...
# nl already exist in database for #54441: passing...
# IC_P_Q1 already exist in database for #54441: passing...
# IC_P_Q2 already exist in database for #54441: passing...
# IC_P_Q4 already exist in database for #54441: passing...
# IC_P_tot already exist in database for #54441: passing...
# LH_P_tot already exist in database for #54441: passing...
# IC_Rc_Q1_avg already exist in database for #54441: passing...
# IC_Rc_Q2_avg already exist in database for #54441: passing...
# IC_Rc_Q4_avg already exist in database for #54441: passing...
# Ohmic_P already exist in database for #54441: passing...
# Separatrix_P already exist in database for #54441: passing...
# IC_Positions already exist in database for #54442: passing...
# LH_Positions already exist in database for #54442: passing...
# Prad already exist in database for #54442: passing...
# Prad_bulk already exist in database for #54442: passing...
# Rext_median already exist in database for #54442: passing...
# Ip already exist in database for #54442: passing...
# nl already exist in database for #54442: passing...
# IC_P_Q1 already exist in database for #54442: passing...
# IC_P_Q2 already exist in database for #54442: passing...
# IC_P_Q4 already exist in database for #54442: passing...
# IC_P_tot already exist in database for #54442: passing...
# LH_P_tot already exist in database for #54442: passing...
# IC_Rc_Q1_avg already exist in database for #54442: passing...
# IC_Rc_Q2_avg already exist in database for #54442: passing...
# IC_Rc_Q4_avg already exist in database for #54442: passing...
# Ohmic_P already exist in database for #54442: passing...
# Separatrix_P already exist in database for #54442: passing...
# IC_Positions already exist in database for #54443: passing...
# LH_Positions already exist in database for #54443: passing...
# Prad already exist in database for #54443: passing...
# Prad_bulk already exist in database for #54443: passing...
# Rext_median already exist in database for #54443: passing...
# Ip already exist in database for #54443: passing...
# nl already exist in database for #54443: passing...
# IC_P_Q1 already exist in database for #54443: passing...
# IC_P_Q2 already exist in database for #54443: passing...
# IC_P_Q4 already exist in database for #54443: passing...
# IC_P_tot already exist in database for #54443: passing...
# LH_P_tot already exist in database for #54443: passing...
# IC_Rc_Q1_avg already exist in database for #54443: passing...
# IC_Rc_Q2_avg already exist in database for #54443: passing...
# IC_Rc_Q4_avg already exist in database for #54443: passing...
# Ohmic_P already exist in database for #54443: passing...
# Separatrix_P already exist in database for #54443: passing...
# IC_Positions already exist in database for #54444: passing...
# LH_Positions already exist in database for #54444: passing...
# Prad already exist in database for #54444: passing...
# Prad_bulk already exist in database for #54444: passing...
# Rext_median already exist in database for #54444: passing...
# Ip already exist in database for #54444: passing...
# nl already exist in database for #54444: passing...
# IC_P_Q1 already exist in database for #54444: passing...
# IC_P_Q2 already exist in database for #54444: passing...
# IC_P_Q4 already exist in database for #54444: passing...
# IC_P_tot already exist in database for #54444: passing...
# LH_P_tot already exist in database for #54444: passing...
# IC_Rc_Q1_avg already exist in database for #54444: passing...
# IC_Rc_Q2_avg already exist in database for #54444: passing...
# IC_Rc_Q4_avg already exist in database for #54444: passing...
# Ohmic_P already exist in database for #54444: passing...
# Separatrix_P already exist in database for #54444: passing...
# IC_Positions already exist in database for #54445: passing...
# LH_Positions already exist in database for #54445: passing...
# Prad already exist in database for #54445: passing...
# Prad_bulk already exist in database for #54445: passing...
# Rext_median already exist in database for #54445: passing...
# Ip already exist in database for #54445: passing...
# nl already exist in database for #54445: passing...
# IC_P_Q1 already exist in database for #54445: passing...
# IC_P_Q2 already exist in database for #54445: passing...
# IC_P_Q4 already exist in database for #54445: passing...
# IC_P_tot already exist in database for #54445: passing...
# LH_P_tot already exist in database for #54445: passing...
# IC_Rc_Q1_avg already exist in database for #54445: passing...
# IC_Rc_Q2_avg already exist in database for #54445: passing...
# IC_Rc_Q4_avg already exist in database for #54445: passing...
# Ohmic_P already exist in database for #54445: passing...
# Separatrix_P already exist in database for #54445: passing...
# IC_Positions already exist in database for #54446: passing...
# LH_Positions already exist in database for #54446: passing...
# Prad already exist in database for #54446: passing...
# Prad_bulk already exist in database for #54446: passing...
# Rext_median already exist in database for #54446: passing...
# Ip already exist in database for #54446: passing...
# nl already exist in database for #54446: passing...
# IC_P_Q1 already exist in database for #54446: passing...
# IC_P_Q2 already exist in database for #54446: passing...
# IC_P_Q4 already exist in database for #54446: passing...
# IC_P_tot already exist in database for #54446: passing...
# LH_P_tot already exist in database for #54446: passing...
# IC_Rc_Q1_avg already exist in database for #54446: passing...
# IC_Rc_Q2_avg already exist in database for #54446: passing...
# IC_Rc_Q4_avg already exist in database for #54446: passing...
# Ohmic_P already exist in database for #54446: passing...
# Separatrix_P already exist in database for #54446: passing...
# IC_Positions already exist in database for #54447: passing...
# LH_Positions already exist in database for #54447: passing...
# Prad already exist in database for #54447: passing...
# Prad_bulk already exist in database for #54447: passing...
# Rext_median already exist in database for #54447: passing...
# Ip already exist in database for #54447: passing...
# nl already exist in database for #54447: passing...
# IC_P_Q1 already exist in database for #54447: passing...
# IC_P_Q2 already exist in database for #54447: passing...
# IC_P_Q4 already exist in database for #54447: passing...
# IC_P_tot already exist in database for #54447: passing...
# LH_P_tot already exist in database for #54447: passing...
# IC_Rc_Q1_avg already exist in database for #54447: passing...
# IC_Rc_Q2_avg already exist in database for #54447: passing...
# IC_Rc_Q4_avg already exist in database for #54447: passing...
# Ohmic_P already exist in database for #54447: passing...
# Separatrix_P already exist in database for #54447: passing...
# IC_Positions already exist in database for #54448: passing...
# LH_Positions already exist in database for #54448: passing...
# Prad already exist in database for #54448: passing...
# Prad_bulk already exist in database for #54448: passing...
# Rext_median already exist in database for #54448: passing...
# Ip already exist in database for #54448: passing...
# nl already exist in database for #54448: passing...
# IC_P_Q1 already exist in database for #54448: passing...
# IC_P_Q2 already exist in database for #54448: passing...
# IC_P_Q4 already exist in database for #54448: passing...
# IC_P_tot already exist in database for #54448: passing...
# LH_P_tot already exist in database for #54448: passing...
# IC_Rc_Q1_avg already exist in database for #54448: passing...
# IC_Rc_Q2_avg already exist in database for #54448: passing...
# IC_Rc_Q4_avg already exist in database for #54448: passing...
# Ohmic_P already exist in database for #54448: passing...
# Separatrix_P already exist in database for #54448: passing...
# IC_Positions already exist in database for #54449: passing...
# LH_Positions already exist in database for #54449: passing...
# Prad already exist in database for #54449: passing...
# Prad_bulk already exist in database for #54449: passing...
# Rext_median already exist in database for #54449: passing...
# Ip already exist in database for #54449: passing...
# nl already exist in database for #54449: passing...
# IC_P_Q1 already exist in database for #54449: passing...
# IC_P_Q2 already exist in database for #54449: passing...
# IC_P_Q4 already exist in database for #54449: passing...
# IC_P_tot already exist in database for #54449: passing...
# LH_P_tot already exist in database for #54449: passing...
# IC_Rc_Q1_avg already exist in database for #54449: passing...
# IC_Rc_Q2_avg already exist in database for #54449: passing...
# IC_Rc_Q4_avg already exist in database for #54449: passing...
# Ohmic_P already exist in database for #54449: passing...
# Separatrix_P already exist in database for #54449: passing...
# IC_Positions already exist in database for #54455: passing...
# LH_Positions already exist in database for #54455: passing...
# Prad already exist in database for #54455: passing...
# Prad_bulk already exist in database for #54455: passing...
# Rext_median already exist in database for #54455: passing...
# Ip already exist in database for #54455: passing...
# nl already exist in database for #54455: passing...
# IC_P_Q1 already exist in database for #54455: passing...
# IC_P_Q2 already exist in database for #54455: passing...
# IC_P_Q4 already exist in database for #54455: passing...
# IC_P_tot already exist in database for #54455: passing...
# LH_P_tot already exist in database for #54455: passing...
# IC_Rc_Q1_avg already exist in database for #54455: passing...
# IC_Rc_Q2_avg already exist in database for #54455: passing...
# IC_Rc_Q4_avg already exist in database for #54455: passing...
# Ohmic_P already exist in database for #54455: passing...
# Separatrix_P already exist in database for #54455: passing...
# IC_Positions already exist in database for #54456: passing...
# LH_Positions already exist in database for #54456: passing...
# Prad already exist in database for #54456: passing...
# Prad_bulk already exist in database for #54456: passing...
# Rext_median already exist in database for #54456: passing...
# Ip already exist in database for #54456: passing...
# nl already exist in database for #54456: passing...
# IC_P_Q1 already exist in database for #54456: passing...
# IC_P_Q2 already exist in database for #54456: passing...
# IC_P_Q4 already exist in database for #54456: passing...
# IC_P_tot already exist in database for #54456: passing...
# LH_P_tot already exist in database for #54456: passing...
# IC_Rc_Q1_avg already exist in database for #54456: passing...
# IC_Rc_Q2_avg already exist in database for #54456: passing...
# IC_Rc_Q4_avg already exist in database for #54456: passing...
# Ohmic_P already exist in database for #54456: passing...
# Separatrix_P already exist in database for #54456: passing...
# IC_Positions already exist in database for #54457: passing...
# LH_Positions already exist in database for #54457: passing...
# Prad already exist in database for #54457: passing...
# Prad_bulk already exist in database for #54457: passing...
# Rext_median already exist in database for #54457: passing...
# Ip already exist in database for #54457: passing...
# nl already exist in database for #54457: passing...
# IC_P_Q1 already exist in database for #54457: passing...
# IC_P_Q2 already exist in database for #54457: passing...
# IC_P_Q4 already exist in database for #54457: passing...
# IC_P_tot already exist in database for #54457: passing...
# LH_P_tot already exist in database for #54457: passing...
# IC_Rc_Q1_avg already exist in database for #54457: passing...
# IC_Rc_Q2_avg already exist in database for #54457: passing...
# IC_Rc_Q4_avg already exist in database for #54457: passing...
# Ohmic_P already exist in database for #54457: passing...
# Separatrix_P already exist in database for #54457: passing...
# IC_Positions already exist in database for #54458: passing...
# LH_Positions already exist in database for #54458: passing...
# Prad already exist in database for #54458: passing...
# Prad_bulk already exist in database for #54458: passing...
# Rext_median already exist in database for #54458: passing...
# Ip already exist in database for #54458: passing...
# nl already exist in database for #54458: passing...
# IC_P_Q1 already exist in database for #54458: passing...
# IC_P_Q2 already exist in database for #54458: passing...
# IC_P_Q4 already exist in database for #54458: passing...
# IC_P_tot already exist in database for #54458: passing...
# LH_P_tot already exist in database for #54458: passing...
# IC_Rc_Q1_avg already exist in database for #54458: passing...
# IC_Rc_Q2_avg already exist in database for #54458: passing...
# IC_Rc_Q4_avg already exist in database for #54458: passing...
# Ohmic_P already exist in database for #54458: passing...
# Separatrix_P already exist in database for #54458: passing...
# IC_Positions already exist in database for #54459: passing...
# LH_Positions already exist in database for #54459: passing...
# Prad already exist in database for #54459: passing...
# Prad_bulk already exist in database for #54459: passing...
# Rext_median already exist in database for #54459: passing...
# Ip already exist in database for #54459: passing...
# nl already exist in database for #54459: passing...
# IC_P_Q1 already exist in database for #54459: passing...
# IC_P_Q2 already exist in database for #54459: passing...
# IC_P_Q4 already exist in database for #54459: passing...
# IC_P_tot already exist in database for #54459: passing...
# LH_P_tot already exist in database for #54459: passing...
# IC_Rc_Q1_avg already exist in database for #54459: passing...
# IC_Rc_Q2_avg already exist in database for #54459: passing...
# IC_Rc_Q4_avg already exist in database for #54459: passing...
# Ohmic_P already exist in database for #54459: passing...
# Separatrix_P already exist in database for #54459: passing...
# IC_Positions already exist in database for #54460: passing...
# LH_Positions already exist in database for #54460: passing...
# Prad already exist in database for #54460: passing...
# Prad_bulk already exist in database for #54460: passing...
# Rext_median already exist in database for #54460: passing...
# Ip already exist in database for #54460: passing...
# nl already exist in database for #54460: passing...
# IC_P_Q1 already exist in database for #54460: passing...
# IC_P_Q2 already exist in database for #54460: passing...
# IC_P_Q4 already exist in database for #54460: passing...
# IC_P_tot already exist in database for #54460: passing...
# LH_P_tot already exist in database for #54460: passing...
# IC_Rc_Q1_avg already exist in database for #54460: passing...
# IC_Rc_Q2_avg already exist in database for #54460: passing...
# IC_Rc_Q4_avg already exist in database for #54460: passing...
# Ohmic_P already exist in database for #54460: passing...
# Separatrix_P already exist in database for #54460: passing...
# IC_Positions already exist in database for #54461: passing...
# LH_Positions already exist in database for #54461: passing...
# Prad already exist in database for #54461: passing...
# Prad_bulk already exist in database for #54461: passing...
# Rext_median already exist in database for #54461: passing...
# Ip already exist in database for #54461: passing...
# nl already exist in database for #54461: passing...
# IC_P_Q1 already exist in database for #54461: passing...
# IC_P_Q2 already exist in database for #54461: passing...
# IC_P_Q4 already exist in database for #54461: passing...
# IC_P_tot already exist in database for #54461: passing...
# LH_P_tot already exist in database for #54461: passing...
# IC_Rc_Q1_avg already exist in database for #54461: passing...
# IC_Rc_Q2_avg already exist in database for #54461: passing...
# IC_Rc_Q4_avg already exist in database for #54461: passing...
# Ohmic_P already exist in database for #54461: passing...
# Separatrix_P already exist in database for #54461: passing...
# IC_Positions already exist in database for #54462: passing...
# LH_Positions already exist in database for #54462: passing...
# Prad already exist in database for #54462: passing...
# Prad_bulk already exist in database for #54462: passing...
# Rext_median already exist in database for #54462: passing...
# Ip already exist in database for #54462: passing...
# nl already exist in database for #54462: passing...
# IC_P_Q1 already exist in database for #54462: passing...
# IC_P_Q2 already exist in database for #54462: passing...
# IC_P_Q4 already exist in database for #54462: passing...
# IC_P_tot already exist in database for #54462: passing...
# LH_P_tot already exist in database for #54462: passing...
# IC_Rc_Q1_avg already exist in database for #54462: passing...
# IC_Rc_Q2_avg already exist in database for #54462: passing...
# IC_Rc_Q4_avg already exist in database for #54462: passing...
# Ohmic_P already exist in database for #54462: passing...
# Separatrix_P already exist in database for #54462: passing...
# IC_Positions already exist in database for #54472: passing...
# LH_Positions already exist in database for #54472: passing...
# Prad already exist in database for #54472: passing...
# Prad_bulk already exist in database for #54472: passing...
# Rext_median already exist in database for #54472: passing...
# Ip already exist in database for #54472: passing...
# nl already exist in database for #54472: passing...
# IC_P_Q1 already exist in database for #54472: passing...
# IC_P_Q2 already exist in database for #54472: passing...
# IC_P_Q4 already exist in database for #54472: passing...
# IC_P_tot already exist in database for #54472: passing...
# LH_P_tot already exist in database for #54472: passing...
# IC_Rc_Q1_avg already exist in database for #54472: passing...
# IC_Rc_Q2_avg already exist in database for #54472: passing...
# IC_Rc_Q4_avg already exist in database for #54472: passing...
# Ohmic_P already exist in database for #54472: passing...
# Separatrix_P already exist in database for #54472: passing...
# IC_Positions already exist in database for #54473: passing...
# LH_Positions already exist in database for #54473: passing...
# Prad already exist in database for #54473: passing...
# Prad_bulk already exist in database for #54473: passing...
# Rext_median already exist in database for #54473: passing...
# Ip already exist in database for #54473: passing...
# nl already exist in database for #54473: passing...
# IC_P_Q1 already exist in database for #54473: passing...
# IC_P_Q2 already exist in database for #54473: passing...
# IC_P_Q4 already exist in database for #54473: passing...
# IC_P_tot already exist in database for #54473: passing...
# LH_P_tot already exist in database for #54473: passing...
# IC_Rc_Q1_avg already exist in database for #54473: passing...
# IC_Rc_Q2_avg already exist in database for #54473: passing...
# IC_Rc_Q4_avg already exist in database for #54473: passing...
# Ohmic_P already exist in database for #54473: passing...
# Separatrix_P already exist in database for #54473: passing...
# IC_Positions already exist in database for #54475: passing...
# LH_Positions already exist in database for #54475: passing...
# Prad already exist in database for #54475: passing...
# Prad_bulk already exist in database for #54475: passing...
# Rext_median already exist in database for #54475: passing...
# Ip already exist in database for #54475: passing...
# nl already exist in database for #54475: passing...
# IC_P_Q1 already exist in database for #54475: passing...
# IC_P_Q2 already exist in database for #54475: passing...
# IC_P_Q4 already exist in database for #54475: passing...
# IC_P_tot already exist in database for #54475: passing...
# LH_P_tot already exist in database for #54475: passing...
# IC_Rc_Q1_avg already exist in database for #54475: passing...
# IC_Rc_Q2_avg already exist in database for #54475: passing...
# IC_Rc_Q4_avg already exist in database for #54475: passing...
# Ohmic_P already exist in database for #54475: passing...
# Separatrix_P already exist in database for #54475: passing...
# IC_Positions already exist in database for #54476: passing...
# LH_Positions already exist in database for #54476: passing...
# Prad already exist in database for #54476: passing...
# Prad_bulk already exist in database for #54476: passing...
# Rext_median already exist in database for #54476: passing...
# Ip already exist in database for #54476: passing...
# nl already exist in database for #54476: passing...
# IC_P_Q1 already exist in database for #54476: passing...
# IC_P_Q2 already exist in database for #54476: passing...
# IC_P_Q4 already exist in database for #54476: passing...
# IC_P_tot already exist in database for #54476: passing...
# LH_P_tot already exist in database for #54476: passing...
# IC_Rc_Q1_avg already exist in database for #54476: passing...
# IC_Rc_Q2_avg already exist in database for #54476: passing...
# IC_Rc_Q4_avg already exist in database for #54476: passing...
# Ohmic_P already exist in database for #54476: passing...
# Separatrix_P already exist in database for #54476: passing...
# IC_Positions already exist in database for #54477: passing...
# LH_Positions already exist in database for #54477: passing...
# Prad already exist in database for #54477: passing...
# Prad_bulk already exist in database for #54477: passing...
# Rext_median already exist in database for #54477: passing...
# Ip already exist in database for #54477: passing...
# nl already exist in database for #54477: passing...
# IC_P_Q1 already exist in database for #54477: passing...
# IC_P_Q2 already exist in database for #54477: passing...
# IC_P_Q4 already exist in database for #54477: passing...
# IC_P_tot already exist in database for #54477: passing...
# LH_P_tot already exist in database for #54477: passing...
# IC_Rc_Q1_avg already exist in database for #54477: passing...
# IC_Rc_Q2_avg already exist in database for #54477: passing...
# IC_Rc_Q4_avg already exist in database for #54477: passing...
# Ohmic_P already exist in database for #54477: passing...
# Separatrix_P already exist in database for #54477: passing...
# IC_Positions already exist in database for #54508: passing...
# LH_Positions already exist in database for #54508: passing...
# Prad already exist in database for #54508: passing...
# Prad_bulk already exist in database for #54508: passing...
# Rext_median already exist in database for #54508: passing...
# Ip already exist in database for #54508: passing...
# nl already exist in database for #54508: passing...
# IC_P_Q1 already exist in database for #54508: passing...
# IC_P_Q2 already exist in database for #54508: passing...
# IC_P_Q4 already exist in database for #54508: passing...
# IC_P_tot already exist in database for #54508: passing...
# LH_P_tot already exist in database for #54508: passing...
# IC_Rc_Q1_avg already exist in database for #54508: passing...
# IC_Rc_Q2_avg already exist in database for #54508: passing...
# IC_Rc_Q4_avg already exist in database for #54508: passing...
# Ohmic_P already exist in database for #54508: passing...
# Separatrix_P already exist in database for #54508: passing...
# IC_Positions already exist in database for #54509: passing...
# LH_Positions already exist in database for #54509: passing...
# Prad already exist in database for #54509: passing...
# Prad_bulk already exist in database for #54509: passing...
# Rext_median already exist in database for #54509: passing...
# Ip already exist in database for #54509: passing...
# nl already exist in database for #54509: passing...
# IC_P_Q1 already exist in database for #54509: passing...
# IC_P_Q2 already exist in database for #54509: passing...
# IC_P_Q4 already exist in database for #54509: passing...
# IC_P_tot already exist in database for #54509: passing...
# LH_P_tot already exist in database for #54509: passing...
# IC_Rc_Q1_avg already exist in database for #54509: passing...
# IC_Rc_Q2_avg already exist in database for #54509: passing...
# IC_Rc_Q4_avg already exist in database for #54509: passing...
# Ohmic_P already exist in database for #54509: passing...
# Separatrix_P already exist in database for #54509: passing...
# IC_Positions already exist in database for #54510: passing...
# LH_Positions already exist in database for #54510: passing...
# Prad already exist in database for #54510: passing...
# Prad_bulk already exist in database for #54510: passing...
# Rext_median already exist in database for #54510: passing...
# Ip already exist in database for #54510: passing...
# nl already exist in database for #54510: passing...
# IC_P_Q1 already exist in database for #54510: passing...
# IC_P_Q2 already exist in database for #54510: passing...
# IC_P_Q4 already exist in database for #54510: passing...
# IC_P_tot already exist in database for #54510: passing...
# LH_P_tot already exist in database for #54510: passing...
# IC_Rc_Q1_avg already exist in database for #54510: passing...
# IC_Rc_Q2_avg already exist in database for #54510: passing...
# IC_Rc_Q4_avg already exist in database for #54510: passing...
# Ohmic_P already exist in database for #54510: passing...
# Separatrix_P already exist in database for #54510: passing...
# IC_Positions already exist in database for #54511: passing...
# LH_Positions already exist in database for #54511: passing...
# Prad already exist in database for #54511: passing...
# Prad_bulk already exist in database for #54511: passing...
# Rext_median already exist in database for #54511: passing...
# Ip already exist in database for #54511: passing...
# nl already exist in database for #54511: passing...
# IC_P_Q1 already exist in database for #54511: passing...
# IC_P_Q2 already exist in database for #54511: passing...
# IC_P_Q4 already exist in database for #54511: passing...
# IC_P_tot already exist in database for #54511: passing...
# LH_P_tot already exist in database for #54511: passing...
# IC_Rc_Q1_avg already exist in database for #54511: passing...
# IC_Rc_Q2_avg already exist in database for #54511: passing...
# IC_Rc_Q4_avg already exist in database for #54511: passing...
# Ohmic_P already exist in database for #54511: passing...
# Separatrix_P already exist in database for #54511: passing...
# IC_Positions already exist in database for #54512: passing...
# LH_Positions already exist in database for #54512: passing...
# Prad already exist in database for #54512: passing...
# Prad_bulk already exist in database for #54512: passing...
# Rext_median already exist in database for #54512: passing...
# Ip already exist in database for #54512: passing...
# nl already exist in database for #54512: passing...
# IC_P_Q1 already exist in database for #54512: passing...
# IC_P_Q2 already exist in database for #54512: passing...
# IC_P_Q4 already exist in database for #54512: passing...
# IC_P_tot already exist in database for #54512: passing...
# LH_P_tot already exist in database for #54512: passing...
# IC_Rc_Q1_avg already exist in database for #54512: passing...
# IC_Rc_Q2_avg already exist in database for #54512: passing...
# IC_Rc_Q4_avg already exist in database for #54512: passing...
# Ohmic_P already exist in database for #54512: passing...
# Separatrix_P already exist in database for #54512: passing...
# IC_Positions already exist in database for #54525: passing...
# LH_Positions already exist in database for #54525: passing...
# Prad already exist in database for #54525: passing...
# Prad_bulk already exist in database for #54525: passing...
# Rext_median already exist in database for #54525: passing...
# Ip already exist in database for #54525: passing...
# nl already exist in database for #54525: passing...
# IC_P_Q1 already exist in database for #54525: passing...
# IC_P_Q2 already exist in database for #54525: passing...
# IC_P_Q4 already exist in database for #54525: passing...
# IC_P_tot already exist in database for #54525: passing...
# LH_P_tot already exist in database for #54525: passing...
# IC_Rc_Q1_avg already exist in database for #54525: passing...
# IC_Rc_Q2_avg already exist in database for #54525: passing...
# IC_Rc_Q4_avg already exist in database for #54525: passing...
# Ohmic_P already exist in database for #54525: passing...
# Separatrix_P already exist in database for #54525: passing...
# IC_Positions already exist in database for #54527: passing...
# LH_Positions already exist in database for #54527: passing...
# Prad already exist in database for #54527: passing...
# Prad_bulk already exist in database for #54527: passing...
# Rext_median already exist in database for #54527: passing...
# Ip already exist in database for #54527: passing...
# nl already exist in database for #54527: passing...
# IC_P_Q1 already exist in database for #54527: passing...
# IC_P_Q2 already exist in database for #54527: passing...
# IC_P_Q4 already exist in database for #54527: passing...
# IC_P_tot already exist in database for #54527: passing...
# LH_P_tot already exist in database for #54527: passing...
# IC_Rc_Q1_avg already exist in database for #54527: passing...
# IC_Rc_Q2_avg already exist in database for #54527: passing...
# IC_Rc_Q4_avg already exist in database for #54527: passing...
# Ohmic_P already exist in database for #54527: passing...
# Separatrix_P already exist in database for #54527: passing...
# IC_Positions already exist in database for #54528: passing...
# LH_Positions already exist in database for #54528: passing...
# Prad already exist in database for #54528: passing...
# Prad_bulk already exist in database for #54528: passing...
# Rext_median already exist in database for #54528: passing...
# Ip already exist in database for #54528: passing...
# nl already exist in database for #54528: passing...
# IC_P_Q1 already exist in database for #54528: passing...
# IC_P_Q2 already exist in database for #54528: passing...
# IC_P_Q4 already exist in database for #54528: passing...
# IC_P_tot already exist in database for #54528: passing...
# LH_P_tot already exist in database for #54528: passing...
# IC_Rc_Q1_avg already exist in database for #54528: passing...
# IC_Rc_Q2_avg already exist in database for #54528: passing...
# IC_Rc_Q4_avg already exist in database for #54528: passing...
# Ohmic_P already exist in database for #54528: passing...
# Separatrix_P already exist in database for #54528: passing...
# IC_Positions already exist in database for #54529: passing...
# LH_Positions already exist in database for #54529: passing...
# Prad already exist in database for #54529: passing...
# Prad_bulk already exist in database for #54529: passing...
# Rext_median already exist in database for #54529: passing...
# Ip already exist in database for #54529: passing...
# nl already exist in database for #54529: passing...
# IC_P_Q1 already exist in database for #54529: passing...
# IC_P_Q2 already exist in database for #54529: passing...
# IC_P_Q4 already exist in database for #54529: passing...
# IC_P_tot already exist in database for #54529: passing...
# LH_P_tot already exist in database for #54529: passing...
# IC_Rc_Q1_avg already exist in database for #54529: passing...
# IC_Rc_Q2_avg already exist in database for #54529: passing...
# IC_Rc_Q4_avg already exist in database for #54529: passing...
# Ohmic_P already exist in database for #54529: passing...
# Separatrix_P already exist in database for #54529: passing...
# IC_Positions already exist in database for #54530: passing...
# LH_Positions already exist in database for #54530: passing...
# Prad already exist in database for #54530: passing...
# Prad_bulk already exist in database for #54530: passing...
# Rext_median already exist in database for #54530: passing...
# Ip already exist in database for #54530: passing...
# nl already exist in database for #54530: passing...
# IC_P_Q1 already exist in database for #54530: passing...
# IC_P_Q2 already exist in database for #54530: passing...
# IC_P_Q4 already exist in database for #54530: passing...
# IC_P_tot already exist in database for #54530: passing...
# LH_P_tot already exist in database for #54530: passing...
# IC_Rc_Q1_avg already exist in database for #54530: passing...
# IC_Rc_Q2_avg already exist in database for #54530: passing...
# IC_Rc_Q4_avg already exist in database for #54530: passing...
# Ohmic_P already exist in database for #54530: passing...
# Separatrix_P already exist in database for #54530: passing...
# IC_Positions already exist in database for #54532: passing...
# LH_Positions already exist in database for #54532: passing...
# Prad already exist in database for #54532: passing...
# Prad_bulk already exist in database for #54532: passing...
# Rext_median already exist in database for #54532: passing...
# Ip already exist in database for #54532: passing...
# nl already exist in database for #54532: passing...
# IC_P_Q1 already exist in database for #54532: passing...
# IC_P_Q2 already exist in database for #54532: passing...
# IC_P_Q4 already exist in database for #54532: passing...
# IC_P_tot already exist in database for #54532: passing...
# LH_P_tot already exist in database for #54532: passing...
# IC_Rc_Q1_avg already exist in database for #54532: passing...
# IC_Rc_Q2_avg already exist in database for #54532: passing...
# IC_Rc_Q4_avg already exist in database for #54532: passing...
# Ohmic_P already exist in database for #54532: passing...
# Separatrix_P already exist in database for #54532: passing...
# IC_Positions already exist in database for #54533: passing...
# LH_Positions already exist in database for #54533: passing...
# Prad already exist in database for #54533: passing...
# Prad_bulk already exist in database for #54533: passing...
# Rext_median already exist in database for #54533: passing...
# Ip already exist in database for #54533: passing...
# nl already exist in database for #54533: passing...
# IC_P_Q1 already exist in database for #54533: passing...
# IC_P_Q2 already exist in database for #54533: passing...
# IC_P_Q4 already exist in database for #54533: passing...
# IC_P_tot already exist in database for #54533: passing...
# LH_P_tot already exist in database for #54533: passing...
# IC_Rc_Q1_avg already exist in database for #54533: passing...
# IC_Rc_Q2_avg already exist in database for #54533: passing...
# IC_Rc_Q4_avg already exist in database for #54533: passing...
# Ohmic_P already exist in database for #54533: passing...
# Separatrix_P already exist in database for #54533: passing...
# IC_Positions already exist in database for #54534: passing...
# LH_Positions already exist in database for #54534: passing...
# Prad already exist in database for #54534: passing...
# Prad_bulk already exist in database for #54534: passing...
# Rext_median already exist in database for #54534: passing...
# Ip already exist in database for #54534: passing...
# nl already exist in database for #54534: passing...
# IC_P_Q1 already exist in database for #54534: passing...
# IC_P_Q2 already exist in database for #54534: passing...
# IC_P_Q4 already exist in database for #54534: passing...
# IC_P_tot already exist in database for #54534: passing...
# LH_P_tot already exist in database for #54534: passing...
# IC_Rc_Q1_avg already exist in database for #54534: passing...
# IC_Rc_Q2_avg already exist in database for #54534: passing...
# IC_Rc_Q4_avg already exist in database for #54534: passing...
# Ohmic_P already exist in database for #54534: passing...
# Separatrix_P already exist in database for #54534: passing...
# IC_Positions already exist in database for #54535: passing...
# LH_Positions already exist in database for #54535: passing...
# Prad already exist in database for #54535: passing...
# ...
# Getting LH_P_tot for #55802
# Getting IC_Rc_Q1_avg for #55802
# Getting IC_Rc_Q2_avg for #55802
# Getting IC_Rc_Q4_avg for #55802
# Getting Ohmic_P for #55802
# WEST!
# noise on channel 9
# channel 9 is interpolated
# sufficient signal to be meaningfull
# radiation profile corrected to take into account radiation at the top
# *********************************************************
# version 1, no reading  of plasma large  radius, assumed to be:
# 2.5m for WEST
# all signals resampled at 1 ms
# .
# MORE RADIATION NEAR BOTTOM DIVERTOR
# .
# Prad=total radiated power [MW]
# Pdivb=estimated radiated power in low divertor [MW]
# Pdivh=estimated radiated power in top divertor [MW]
# Pbulk= estimated radiated power in bulk [MW]
# Pchan=radiated power on each channel integrated toroidally [MW]
# trad=time  [s]
# *********************************************************
# Getting Separatrix_P for #55802
# Getting IC_Positions for #55803
# Getting LH_Positions for #55803
# WEST!
# noise on channel 9
# channel 9 is interpolated
# sufficient signal to be meaningfull
# radiation profile corrected to take into account radiation at the top
# *********************************************************
# version 1, no reading  of plasma large  radius, assumed to be:
# 2.5m for WEST
# all signals resampled at 1 ms
# .
# MORE RADIATION NEAR BOTTOM DIVERTOR
# .
# Prad=total radiated power [MW]
# Pdivb=estimated radiated power in low divertor [MW]
# Pdivh=estimated radiated power in top divertor [MW]
# Pbulk= estimated radiated power in bulk [MW]
# Pchan=radiated power on each channel integrated toroidally [MW]
# trad=time  [s]
# *********************************************************
# Getting Prad for #55803
# WEST!
# noise on channel 9
# channel 9 is interpolated
# sufficient signal to be meaningfull
# radiation profile corrected to take into account radiation at the top
# *********************************************************
# version 1, no reading  of plasma large  radius, assumed to be:
# 2.5m for WEST
# all signals resampled at 1 ms
# .
# MORE RADIATION NEAR BOTTOM DIVERTOR
# .
# Prad=total radiated power [MW]
# Pdivb=estimated radiated power in low divertor [MW]
# Pdivh=estimated radiated power in top divertor [MW]
# Pbulk= estimated radiated power in bulk [MW]
# Pchan=radiated power on each channel integrated toroidally [MW]
# trad=time  [s]
# *********************************************************
# Getting Prad_bulk for #55803
# Getting Rext_median for #55803
# Getting Ip for #55803
# Getting nl for #55803
# Getting IC_P_Q1 for #55803
# Getting IC_P_Q2 for #55803
# Getting IC_P_Q4 for #55803
# Getting IC_P_tot for #55803
# Getting LH_P_tot for #55803
# Getting IC_Rc_Q1_avg for #55803
# Getting IC_Rc_Q2_avg for #55803
# Getting IC_Rc_Q4_avg for #55803
# Getting Ohmic_P for #55803
# WEST!
# noise on channel 9
# channel 9 is interpolated
# sufficient signal to be meaningfull
# radiation profile corrected to take into account radiation at the top
# *********************************************************
# version 1, no reading  of plasma large  radius, assumed to be:
# 2.5m for WEST
# all signals resampled at 1 ms
# .
# MORE RADIATION NEAR BOTTOM DIVERTOR
# .
# Prad=total radiated power [MW]
# Pdivb=estimated radiated power in low divertor [MW]
# Pdivh=estimated radiated power in top divertor [MW]
# Pbulk= estimated radiated power in bulk [MW]
# Pchan=radiated power on each channel integrated toroidally [MW]
# trad=time  [s]
# *********************************************************
# Getting Separatrix_P for #55803
# Getting IC_Positions for #55804
# Getting LH_Positions for #55804
# WEST!
# noise on channel 9
# channel 9 is interpolated
# sufficient signal to be meaningfull
# radiation profile corrected to take into account radiation at the top
# *********************************************************
# version 1, no reading  of plasma large  radius, assumed to be:
# 2.5m for WEST
# all signals resampled at 1 ms
# .
# MORE RADIATION NEAR BOTTOM DIVERTOR
# .
# Prad=total radiated power [MW]
# Pdivb=estimated radiated power in low divertor [MW]
# Pdivh=estimated radiated power in top divertor [MW]
# Pbulk= estimated radiated power in bulk [MW]
# Pchan=radiated power on each channel integrated toroidally [MW]
# trad=time  [s]
# *********************************************************
# Getting Prad for #55804
# WEST!
# noise on channel 9
# channel 9 is interpolated
# sufficient signal to be meaningfull
# radiation profile corrected to take into account radiation at the top
# *********************************************************
# version 1, no reading  of plasma large  radius, assumed to be:
# 2.5m for WEST
# all signals resampled at 1 ms
# .
# MORE RADIATION NEAR BOTTOM DIVERTOR
# .
# Prad=total radiated power [MW]
# Pdivb=estimated radiated power in low divertor [MW]
# Pdivh=estimated radiated power in top divertor [MW]
# Pbulk= estimated radiated power in bulk [MW]
# Pchan=radiated power on each channel integrated toroidally [MW]
# trad=time  [s]
# *********************************************************
# Getting Prad_bulk for #55804
# Getting Rext_median for #55804
# Getting Ip for #55804
# Getting nl for #55804
# Getting IC_P_Q1 for #55804
# Getting IC_P_Q2 for #55804
# Getting IC_P_Q4 for #55804
# Getting IC_P_tot for #55804
# Getting LH_P_tot for #55804
# Getting IC_Rc_Q1_avg for #55804
# Getting IC_Rc_Q2_avg for #55804
# Getting IC_Rc_Q4_avg for #55804
# Getting Ohmic_P for #55804
# WEST!
# noise on channel 9
# channel 9 is interpolated
# sufficient signal to be meaningfull
# radiation profile corrected to take into account radiation at the top
# *********************************************************
# version 1, no reading  of plasma large  radius, assumed to be:
# 2.5m for WEST
# all signals resampled at 1 ms
# .
# MORE RADIATION NEAR BOTTOM DIVERTOR
# .
# Prad=total radiated power [MW]
# Pdivb=estimated radiated power in low divertor [MW]
# Pdivh=estimated radiated power in top divertor [MW]
# Pbulk= estimated radiated power in bulk [MW]
# Pchan=radiated power on each channel integrated toroidally [MW]
# trad=time  [s]
# *********************************************************
# Getting Separatrix_P for #55804
# Getting IC_Positions for #55805
# Getting LH_Positions for #55805
# WEST!
# noise on channel 9
# channel 9 is interpolated
# sufficient signal to be meaningfull
# radiation profile corrected to take into account radiation at the top
# *********************************************************
# version 1, no reading  of plasma large  radius, assumed to be:
# 2.5m for WEST
# all signals resampled at 1 ms
# .
# MORE RADIATION NEAR BOTTOM DIVERTOR
# .
# Prad=total radiated power [MW]
# Pdivb=estimated radiated power in low divertor [MW]
# Pdivh=estimated radiated power in top divertor [MW]
# Pbulk= estimated radiated power in bulk [MW]
# Pchan=radiated power on each channel integrated toroidally [MW]
# trad=time  [s]
# *********************************************************
# Getting Prad for #55805
# WEST!
# noise on channel 9
# channel 9 is interpolated
# sufficient signal to be meaningfull
# radiation profile corrected to take into account radiation at the top
# *********************************************************
# version 1, no reading  of plasma large  radius, assumed to be:
# 2.5m for WEST
# all signals resampled at 1 ms
# .
# MORE RADIATION NEAR BOTTOM DIVERTOR
# .
# Prad=total radiated power [MW]
# Pdivb=estimated radiated power in low divertor [MW]
# Pdivh=estimated radiated power in top divertor [MW]
# Pbulk= estimated radiated power in bulk [MW]
# Pchan=radiated power on each channel integrated toroidally [MW]
# trad=time  [s]
# *********************************************************
# Getting Prad_bulk for #55805
# Getting Rext_median for #55805
# Getting Ip for #55805
# Getting nl for #55805
# Getting IC_P_Q1 for #55805
# Getting IC_P_Q2 for #55805
# Getting IC_P_Q4 for #55805
# Getting IC_P_tot for #55805
# Getting LH_P_tot for #55805
# Getting IC_Rc_Q1_avg for #55805
# Getting IC_Rc_Q2_avg for #55805
# Getting IC_Rc_Q4_avg for #55805
# Getting Ohmic_P for #55805
# WEST!
# noise on channel 9
# channel 9 is interpolated
# sufficient signal to be meaningfull
# radiation profile corrected to take into account radiation at the top
# *********************************************************
# version 1, no reading  of plasma large  radius, assumed to be:
# 2.5m for WEST
# all signals resampled at 1 ms
# .
# MORE RADIATION NEAR BOTTOM DIVERTOR
# .
# Prad=total radiated power [MW]
# Pdivb=estimated radiated power in low divertor [MW]
# Pdivh=estimated radiated power in top divertor [MW]
# Pbulk= estimated radiated power in bulk [MW]
# Pchan=radiated power on each channel integrated toroidally [MW]
# trad=time  [s]
# *********************************************************
# Getting Separatrix_P for #55805
# Getting IC_Positions for #55807
# Getting LH_Positions for #55807
# WEST!
# noise on channel 9
# channel 9 is interpolated
# sufficient signal to be meaningfull
# radiation profile corrected to take into account radiation at the top
# *********************************************************
# version 1, no reading  of plasma large  radius, assumed to be:
# 2.5m for WEST
# all signals resampled at 1 ms
# .
# MORE RADIATION NEAR TOP DIVERTOR
# .
# Prad=total radiated power [MW]
# Pdivb=estimated radiated power in low divertor [MW]
# Pdivh=estimated radiated power in top divertor [MW]
# Pbulk= estimated radiated power in bulk [MW]
# Pchan=radiated power on each channel integrated toroidally [MW]
# trad=time  [s]
# *********************************************************
# Getting Prad for #55807
# WEST!
# noise on channel 9
# channel 9 is interpolated
# sufficient signal to be meaningfull
# radiation profile corrected to take into account radiation at the top
# *********************************************************
# version 1, no reading  of plasma large  radius, assumed to be:
# 2.5m for WEST
# all signals resampled at 1 ms
# .
# MORE RADIATION NEAR TOP DIVERTOR
# .
# Prad=total radiated power [MW]
# Pdivb=estimated radiated power in low divertor [MW]
# Pdivh=estimated radiated power in top divertor [MW]
# Pbulk= estimated radiated power in bulk [MW]
# Pchan=radiated power on each channel integrated toroidally [MW]
# trad=time  [s]
# *********************************************************
# Getting Prad_bulk for #55807
# Getting Rext_median for #55807
# Getting Ip for #55807
# Getting nl for #55807
# Getting IC_P_Q1 for #55807
# Getting IC_P_Q2 for #55807
# Getting IC_P_Q4 for #55807
# Getting IC_P_tot for #55807
# Getting LH_P_tot for #55807
# Getting IC_Rc_Q1_avg for #55807
# Getting IC_Rc_Q2_avg for #55807
# Getting IC_Rc_Q4_avg for #55807
# Getting Ohmic_P for #55807
# WEST!
# noise on channel 9
# channel 9 is interpolated
# sufficient signal to be meaningfull
# radiation profile corrected to take into account radiation at the top
# *********************************************************
# version 1, no reading  of plasma large  radius, assumed to be:
# 2.5m for WEST
# all signals resampled at 1 ms
# .
# MORE RADIATION NEAR TOP DIVERTOR
# .
# Prad=total radiated power [MW]
# Pdivb=estimated radiated power in low divertor [MW]
# Pdivh=estimated radiated power in top divertor [MW]
# Pbulk= estimated radiated power in bulk [MW]
# Pchan=radiated power on each channel integrated toroidally [MW]
# trad=time  [s]
# *********************************************************
# Getting Separatrix_P for #55807
# Getting IC_Positions for #55808
# Getting LH_Positions for #55808
# WEST!
# noise on channel 9
# channel 9 is interpolated
# sufficient signal to be meaningfull
# radiation profile corrected to take into account radiation at the top
# *********************************************************
# version 1, no reading  of plasma large  radius, assumed to be:
# 2.5m for WEST
# all signals resampled at 1 ms
# .
# MORE RADIATION NEAR TOP DIVERTOR
# .
# Prad=total radiated power [MW]
# Pdivb=estimated radiated power in low divertor [MW]
# Pdivh=estimated radiated power in top divertor [MW]
# Pbulk= estimated radiated power in bulk [MW]
# Pchan=radiated power on each channel integrated toroidally [MW]
# trad=time  [s]
# *********************************************************
# Getting Prad for #55808
# WEST!
# noise on channel 9
# channel 9 is interpolated
# sufficient signal to be meaningfull
# radiation profile corrected to take into account radiation at the top
# *********************************************************
# version 1, no reading  of plasma large  radius, assumed to be:
# 2.5m for WEST
# all signals resampled at 1 ms
# .
# MORE RADIATION NEAR TOP DIVERTOR
# .
# Prad=total radiated power [MW]
# Pdivb=estimated radiated power in low divertor [MW]
# Pdivh=estimated radiated power in top divertor [MW]
# Pbulk= estimated radiated power in bulk [MW]
# Pchan=radiated power on each channel integrated toroidally [MW]
# trad=time  [s]
# *********************************************************
# Getting Prad_bulk for #55808
# Getting Rext_median for #55808
# Getting Ip for #55808
# Getting nl for #55808
# Getting IC_P_Q1 for #55808
# Getting IC_P_Q2 for #55808
# Getting IC_P_Q4 for #55808
# Getting IC_P_tot for #55808
# Getting LH_P_tot for #55808
# Getting IC_Rc_Q1_avg for #55808
# Getting IC_Rc_Q2_avg for #55808
# Getting IC_Rc_Q4_avg for #55808
# Getting Ohmic_P for #55808
# WEST!
# noise on channel 9
# channel 9 is interpolated
# sufficient signal to be meaningfull
# radiation profile corrected to take into account radiation at the top
# *********************************************************
# version 1, no reading  of plasma large  radius, assumed to be:
# 2.5m for WEST
# all signals resampled at 1 ms
# .
# MORE RADIATION NEAR TOP DIVERTOR
# .
# Prad=total radiated power [MW]
# Pdivb=estimated radiated power in low divertor [MW]
# Pdivh=estimated radiated power in top divertor [MW]
# Pbulk= estimated radiated power in bulk [MW]
# Pchan=radiated power on each channel integrated toroidally [MW]
# trad=time  [s]
# *********************************************************
# Getting Separatrix_P for #55808
# Getting IC_Positions for #55809
# Getting LH_Positions for #55809
# WEST!
# noise on channel 9
# channel 9 is interpolated
# sufficient signal to be meaningfull
# radiation profile corrected to take into account radiation at the top
# *********************************************************
# version 1, no reading  of plasma large  radius, assumed to be:
# 2.5m for WEST
# all signals resampled at 1 ms
# .
# MORE RADIATION NEAR TOP DIVERTOR
# .
# Prad=total radiated power [MW]
# Pdivb=estimated radiated power in low divertor [MW]
# Pdivh=estimated radiated power in top divertor [MW]
# Pbulk= estimated radiated power in bulk [MW]
# Pchan=radiated power on each channel integrated toroidally [MW]
# trad=time  [s]
# *********************************************************
# Getting Prad for #55809
# WEST!
# noise on channel 9
# channel 9 is interpolated
# sufficient signal to be meaningfull
# radiation profile corrected to take into account radiation at the top
# *********************************************************
# version 1, no reading  of plasma large  radius, assumed to be:
# 2.5m for WEST
# all signals resampled at 1 ms
# .
# MORE RADIATION NEAR TOP DIVERTOR
# .
# Prad=total radiated power [MW]
# Pdivb=estimated radiated power in low divertor [MW]
# Pdivh=estimated radiated power in top divertor [MW]
# Pbulk= estimated radiated power in bulk [MW]
# Pchan=radiated power on each channel integrated toroidally [MW]
# trad=time  [s]
# *********************************************************
# Getting Prad_bulk for #55809
# Getting Rext_median for #55809
# Getting Ip for #55809
# Getting nl for #55809
# Getting IC_P_Q1 for #55809
# Getting IC_P_Q2 for #55809
# Getting IC_P_Q4 for #55809
# Getting IC_P_tot for #55809
# Getting LH_P_tot for #55809
# Getting IC_Rc_Q1_avg for #55809
# Getting IC_Rc_Q2_avg for #55809
# Getting IC_Rc_Q4_avg for #55809
# Getting Ohmic_P for #55809
# WEST!
# noise on channel 9
# channel 9 is interpolated
# sufficient signal to be meaningfull
# radiation profile corrected to take into account radiation at the top
# *********************************************************
# version 1, no reading  of plasma large  radius, assumed to be:
# 2.5m for WEST
# all signals resampled at 1 ms
# .
# MORE RADIATION NEAR TOP DIVERTOR
# .
# Prad=total radiated power [MW]
# Pdivb=estimated radiated power in low divertor [MW]
# Pdivh=estimated radiated power in top divertor [MW]
# Pbulk= estimated radiated power in bulk [MW]
# Pchan=radiated power on each channel integrated toroidally [MW]
# trad=time  [s]
# *********************************************************
# Getting Separatrix_P for #55809

# %%
pulse
# Out:
# 55809

# %%
db.list_signal(55015)
# Out:
# ['Ag18',
#  'Ag19',
#  'IC_Frequencies',
#  'IC_P_Q1',
#  'IC_P_Q2',
#  'IC_P_Q4',
#  'IC_P_tot',
#  'IC_Positions',
#  'IC_Rc_Q1_avg',
#  'IC_Rc_Q2_avg',
#  'IC_Rc_Q4_avg',
#  'IC_Vacuum_Q1_left',
#  'IC_Vacuum_Q1_right',
#  'IC_Vacuum_Q2_left',
#  'IC_Vacuum_Q2_right',
#  'IC_Vacuum_Q4_left',
#  'IC_Vacuum_Q4_right',
#  'IC_Voltage_left_lower_Q1',
#  'IC_Voltage_left_lower_Q2',
#  'IC_Voltage_left_lower_Q4',
#  'IC_Voltage_left_upper_Q1',
#  'IC_Voltage_left_upper_Q2',
#  'IC_Voltage_left_upper_Q4',
#  'IC_Voltage_right_lower_Q1',
#  'IC_Voltage_right_lower_Q2',
#  'IC_Voltage_right_lower_Q4',
#  'IC_Voltage_right_upper_Q1',
#  'IC_Voltage_right_upper_Q2',
#  'IC_Voltage_right_upper_Q4',
#  'IC_delta_phi_toro_Q1_Bot_LmR',
#  'IC_delta_phi_toro_Q1_Top_LmR',
#  'IC_delta_phi_toro_Q2_Bot_LmR',
#  'IC_delta_phi_toro_Q2_Top_LmR',
#  'IC_delta_phi_toro_Q4_Bot_LmR',
#  'IC_delta_phi_toro_Q4_Top_LmR',
#  'Ip',
#  'LH_P_tot',
#  'LH_Positions',
#  'LPA',
#  'Langmuir_LHCD1',
#  'Langmuir_LHCD2',
#  'Langmuir_LHCD3',
#  'Langmuir_LHCD4',
#  'Langmuir_LHCD5',
#  'Langmuir_LHCD6',
#  'Langmuir_LHCD7',
#  'Langmuir_LHCD8',
#  'Neutron1',
#  'Ohmic_P',
#  'Prad',
#  'Prad_bulk',
#  'Rext_median',
#  'Separatrix_P',
#  'nl']

# %%
#db.delete_signals(['Vloop'])
